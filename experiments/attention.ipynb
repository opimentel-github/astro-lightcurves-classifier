# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../fuzzy-torch') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.utils import get_models_from_rootdir

mode = 'pre-training'
survey_name = 'alerceZTFv7.1'
kf = 0
set_name = f'{kf}@s_val' # s_train r_train s_val r_val r_test
rootdir = f'../save/experiments/{set_name}'
cset_name = set_name.split('@')[-1]
model_names = get_models_from_rootdir(f'{rootdir}/{mode}', fext='attnscores')
for kmn,model_name in enumerate(model_names):
    print(f'[{kmn}] {model_name}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [0] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=2°enc-emb=g64-g64-g64.r64-r64-r64°dec-emb=g64-g64.r64-r64°mode=pre-training°rsc=0
# [1] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=4°enc-emb=g64-g64-g64.r64-r64-r64°dec-emb=g64-g64.r64-r64°mode=pre-training°rsc=0
# [2] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=8°enc-emb=g64-g64-g64.r64-r64-r64°dec-emb=g64-g64.r64-r64°mode=pre-training°rsc=0

# %%
# %load_ext autoreload
# %autoreload 2

idx = 2
new_model_name = model_names[idx]
print(new_model_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=8°enc-emb=g64-g64-g64.r64-r64-r64°dec-emb=g64-g64.r64-r64°mode=pre-training°rsc=0

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.attention import plot_attention_statistics

attn_kwargs = {
    'mode':mode,
    'N':20,
    'bins_xrange':[0, 1],
    'bins_yrange':[0, 1],
    'extent':[0, 1, 0, 1],
}
plot_attention_statistics(rootdir, new_model_name, 'obse_min_max', 'obs_min_max', **attn_kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [0][1#] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=8°enc-emb=g64-g64-g64.r64-r64-r64°dec-emb=g64-g64.r64-r64°mode=pre-training°rsc=0
# {'i': 3, 'b': 'g', 'c': 'SNIa', 'b_len': 48, 'attn_entropy': 3.4538724, 'attn_entropy/len': 0.07195567588011424, 'attn_scores': 0.1024741604924202, 'attn_scores_min_max': 0.9411129355430603, 'obs': 0.06428573858633412, 'obs_min_max': 0.15687919734844707, 'obse': 0.009640600915945622, 'obse_min_max': 0.4244485421798703, 'wobs': 691.68118216196, 'wobs_min_max': 0.09953162258557276, 'lineal_trend': 0.008469451250286511, 'peak_day': 18.991127052697784, 'day': 3.8918662420373824, 'days_from_peak': -18.03701101901481}

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.attention import plot_attention_statistics

attn_kwargs1 = {
    'mode':mode,
    'N':80,
    'bins_xrange':[-20, 35],
    'bins_yrange':[-.04, .04],
}
attn_kwargs2 = {
    'mode':mode,
    'N':70,
    'bins_xrange':[-20, 4],
    'bins_yrange':[-.001, .01],
}
plot_attention_statistics(rootdir, new_model_name, 'days_from_peak', 'lineal_trend', **attn_kwargs1)
plot_attention_statistics(rootdir, new_model_name, 'days_from_peak', 'lineal_trend', **attn_kwargs2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [0][1#] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=8°enc-emb=g64-g64-g64.r64-r64-r64°dec-emb=g64-g64.r64-r64°mode=pre-training°rsc=0
# {'i': 3, 'b': 'g', 'c': 'SNIa', 'b_len': 48, 'attn_entropy': 3.4538724, 'attn_entropy/len': 0.07195567588011424, 'attn_scores': 0.1024741604924202, 'attn_scores_min_max': 0.9411129355430603, 'obs': 0.06428573858633412, 'obs_min_max': 0.15687919734844707, 'obse': 0.009640600915945622, 'obse_min_max': 0.4244485421798703, 'wobs': 691.68118216196, 'wobs_min_max': 0.09953162258557276, 'lineal_trend': 0.008469451250286511, 'peak_day': 18.991127052697784, 'day': 3.8918662420373824, 'days_from_peak': -18.03701101901481}
# [0][1#] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=8°enc-emb=g64-g64-g64.r64-r64-r64°dec-emb=g64-g64.r64-r64°mode=pre-training°rsc=0
# {'i': 3, 'b': 'g', 'c': 'SNIa', 'b_len': 48, 'attn_entropy': 3.4538724, 'attn_entropy/len': 0.07195567588011424, 'attn_scores': 0.1024741604924202, 'attn_scores_min_max': 0.9411129355430603, 'obs': 0.06428573858633412, 'obs_min_max': 0.15687919734844707, 'obse': 0.009640600915945622, 'obse_min_max': 0.4244485421798703, 'wobs': 691.68118216196, 'wobs_min_max': 0.09953162258557276, 'lineal_trend': 0.008469451250286511, 'peak_day': 18.991127052697784, 'day': 3.8918662420373824, 'days_from_peak': -18.03701101901481}
