# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../fuzzy-torch') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.utils import get_models_from_rootdir

mode = 'fine-tuning'
survey_name = 'alerceZTFv7.1'
kf = 0
set_name = f'{kf}@r_test' # s_train r_train s_val r_val r_test
rootdir = f'../save/experiments/{set_name}'
cset_name = set_name.split('@')[-1]
model_names = get_models_from_rootdir(f'{rootdir}/{mode}', fext='attnscores')
for kmn,model_name in enumerate(model_names):
    print(f'[{kmn}] {model_name}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [0] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=16°enc-emb=g32-g32-g32.r32-r32-r32°dec-emb=g32-g32.r32-r32°mode=fine-tuning°rsc=0

# %%
# %load_ext autoreload
# %autoreload 2

idx = 0
new_model_name = model_names[idx]
print(new_model_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=16°enc-emb=g32-g32-g32.r32-r32-r32°dec-emb=g32-g32.r32-r32°mode=fine-tuning°rsc=0

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.attention import plot_attention_statistics

attn_kwargs = {
    'mode':mode,
    'N':20,
    'bins_xrange':[0, 1],
    'bins_yrange':[0, 1],
    'extent':[0, 1, 0, 1],
}
plot_attention_statistics(rootdir, new_model_name, 'obse_min_max', 'obs_min_max', **attn_kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [0][1#] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=16°enc-emb=g32-g32-g32.r32-r32-r32°dec-emb=g32-g32.r32-r32°mode=fine-tuning°rsc=0
# {'i': 3, 'b': 'g', 'c': 'SLSN', 'b_len': 36, 'attn_entropy': 3.4342752, 'attn_entropy/len': 0.09539653195275201, 'attn_scores': 0.03853578865528107, 'attn_scores_min_max': 0.21103644371032715, 'obs': 0.061633552348067965, 'obs_min_max': 0.0683803427342196, 'obse': 0.008716140977638176, 'obse_min_max': 0.03373086416660291, 'wobs': 716.9100155706639, 'wobs_min_max': 0.3461833746487583, 'lineal_trend': 0.018192538029101212, 'peak_day': 26.870057799853384, 'day': 2.9184952997602522, 'days_from_peak': -25.930614121224306}

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.attention import plot_attention_statistics

attn_kwargs1 = {
    'mode':mode,
    'N':80,
    'bins_xrange':[-20, 35],
    'bins_yrange':[-.04, .04],
}
attn_kwargs2 = {
    'mode':mode,
    'N':70,
    'bins_xrange':[-20, 4],
    'bins_yrange':[-.001, .01],
}
plot_attention_statistics(rootdir, new_model_name, 'days_from_peak', 'lineal_trend', **attn_kwargs1)
plot_attention_statistics(rootdir, new_model_name, 'days_from_peak', 'lineal_trend', **attn_kwargs2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [0][1#] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=16°enc-emb=g32-g32-g32.r32-r32-r32°dec-emb=g32-g32.r32-r32°mode=fine-tuning°rsc=0
# {'i': 3, 'b': 'g', 'c': 'SLSN', 'b_len': 36, 'attn_entropy': 3.4342752, 'attn_entropy/len': 0.09539653195275201, 'attn_scores': 0.03853578865528107, 'attn_scores_min_max': 0.21103644371032715, 'obs': 0.061633552348067965, 'obs_min_max': 0.0683803427342196, 'obse': 0.008716140977638176, 'obse_min_max': 0.03373086416660291, 'wobs': 716.9100155706639, 'wobs_min_max': 0.3461833746487583, 'lineal_trend': 0.018192538029101212, 'peak_day': 26.870057799853384, 'day': 2.9184952997602522, 'days_from_peak': -25.930614121224306}
# [0][1#] mdl=ParallelTimeSelfAttn°in-dims=2°te-dims=16°enc-emb=g32-g32-g32.r32-r32-r32°dec-emb=g32-g32.r32-r32°mode=fine-tuning°rsc=0
# {'i': 3, 'b': 'g', 'c': 'SLSN', 'b_len': 36, 'attn_entropy': 3.4342752, 'attn_entropy/len': 0.09539653195275201, 'attn_scores': 0.03853578865528107, 'attn_scores_min_max': 0.21103644371032715, 'obs': 0.061633552348067965, 'obs_min_max': 0.0683803427342196, 'obse': 0.008716140977638176, 'obse_min_max': 0.03373086416660291, 'wobs': 716.9100155706639, 'wobs_min_max': 0.3461833746487583, 'lineal_trend': 0.018192538029101212, 'peak_day': 26.870057799853384, 'day': 2.9184952997602522, 'days_from_peak': -25.930614121224306}
