# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../fuzzy-torch') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module
sys.path.append('../../sne-lightcurves-synthetic') # or just install the module

# %% [markdown]
# # search model's results

# %%
# %load_ext autoreload
# %autoreload 2
from flamingchoripan.files import search_for_filedirs

survey_name = 'alerceZTFv5.1'
root_folder = f'../save/experiments/'
for fext in ['exprec', 'expmet']:
    print(f'fext: {fext}')
    filedirs = search_for_filedirs(root_folder, fext=fext, verbose=0)
    cfiledirs = [fd.split('/')[-2] for fd in filedirs] # delete id
    for cfiledir in set(cfiledirs):
        print(f' - cfiledir: {cfiledir} (ids: {cfiledirs.count(cfiledir)})')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# fext: exprec
#  - cfiledir: mdl=SerialRNN°in-dims=2°te-dims=2°enc-emb=64.64°dec-emb=64.64°cell=GRU°bi=False°ef-be=1e-10 (ids: 1)
# fext: expmet
#  - cfiledir: mdl=SerialRNN°in-dims=2°te-dims=2°enc-emb=64.64°dec-emb=64.64°cell=GRU°bi=False°ef-be=1e-10 (ids: 1)

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.plots import plot_baccu_f1score

plot_baccu_f1score(root_folder)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl=SerialRNN°in-dims=2°te-dims=2°enc-emb=64.64°dec-emb=64.64°cell=GRU°bi=False°ef-be=1e-10
# model_name: mdl=SerialRNN°in-dims=2°te-dims=2°enc-emb=64.64°dec-emb=64.64°cell=GRU°bi=False°ef-be=1e-10

# %% [markdown]
# # mse vs time

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.plots import plot_mse

plot_mse(root_folder)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl=SerialRNN°in-dims=2°te-dims=2°enc-emb=64.64°dec-emb=64.64°cell=GRU°bi=False°ef-be=1e-10

# %% [markdown]
# # f1score vs mse

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.plots import plot_f1score_mse

plot_f1score_mse(root_folder)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl=SerialRNN°in-dims=2°te-dims=2°enc-emb=64.64°dec-emb=64.64°cell=GRU°bi=False°ef-be=1e-10
# model_name: mdl=SerialRNN°in-dims=2°te-dims=2°enc-emb=64.64°dec-emb=64.64°cell=GRU°bi=False°ef-be=1e-10
# /home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/ipykernel_launcher.py:5: RankWarning: Polyfit may be poorly conditioned
#   """
# /home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/ipykernel_launcher.py:5: RankWarning: Polyfit may be poorly conditioned
#   """

# %% [markdown]
# # Temporal encoding

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.plots import plot_te_scores

plot_te_scores(root_folder, error_scale=1.5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# /home/opimentel/TESIS/astrolightcurvesclassifier/src/results/utils.py:69: UserWarning: not same samples: [5, 5, 5, 5, 4, 5, 4, 5]
#   def get_metrics_from_models(root_folder, model_names, metric_name, fext, # fix
# /home/opimentel/TESIS/astrolightcurvesclassifier/src/results/utils.py:69: UserWarning: not same samples: [5, 5, 5, 5, 4, 5, 4, 5]
#   def get_metrics_from_models(root_folder, model_names, metric_name, fext, # fix
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0

# %% [markdown]
# # accuracy & f1score

# %% [markdown]
# # Precision & recall

# %%
# %load_ext autoreload
# %autoreload 2
from src.results.plots import plot_precision_recall

plot_precision_recall(root_folder, error_scale=0.5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# ../flamingchoripan/dataScience/statistics.py:51: UserWarning: calculating standar error as std when using 1 sample
#   warnings.warn(f'calculating standar error as std when using 1 sample')
# /home/opimentel/TESIS/astrolightcurvesclassifier/src/results/utils.py:69: UserWarning: not same samples: [3, 5, 4, 5, 1, 5, 2, 5]
#   def get_metrics_from_models(root_folder, model_names, metric_name, fext, # fix
# ../flamingchoripan/dataScience/statistics.py:51: UserWarning: calculating standar error as std when using 1 sample
#   warnings.warn(f'calculating standar error as std when using 1 sample')
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# /home/opimentel/TESIS/astrolightcurvesclassifier/src/results/utils.py:69: UserWarning: not same samples: [3, 5, 4, 5, 1, 5, 2, 5]
#   def get_metrics_from_models(root_folder, model_names, metric_name, fext, # fix

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from ipywidgets import interact, fixed
from flamingchoripan.myUtils.files import search_for_filedirs
from src.results.plots import plot_precision_recall_classes

def interact_f(model_name):
    return plot_precision_recall_classes(root_folder, model_name)

filedirs = search_for_filedirs(root_folder, fext='expmet', verbose=0)
model_names = list(set([fd.split('/')[-2] for fd in filedirs]))
interact(interact_f, model_name=model_names)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# interactive(children=(Dropdown(description='model_name', options=('mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1…
# <function __main__.interact_f(model_name)>

# %%
# %load_ext autoreload
# %autoreload 2
from src.results.plots import plot_training_losses

plot_training_losses(root_folder)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0

# %% [markdown]
# # metrics & training times table

# %%
# %load_ext autoreload
# %autoreload 2
from src.results.latex_tables import latex_table_metrics_days

target_days = [15, 30, 60]
latex_table_metrics_days(root_folder, target_days)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \begin{table*}
# \centering
# \caption{???}
# \label{results_columns}\vspace{.1cm}
# \begin{tabular}{lcccccc|cccccc}\rowcolor[HTML]{343434}
#
# {\color[HTML]{FFFFFF}mdl}}&{\color[HTML]{FFFFFF}inD}&{\color[HTML]{FFFFFF}teD}&{\color[HTML]{FFFFFF}cell}&{\color[HTML]{FFFFFF}rnnL}&{\color[HTML]{FFFFFF}rnnU}&{\color[HTML]{FFFFFF}bi}&{\color[HTML]{FFFFFF}$baccu|^{15.0d}$}&{\color[HTML]{FFFFFF}$baccu|^{30.0d}$}&{\color[HTML]{FFFFFF}$baccu|^{60.0d}$}&{\color[HTML]{FFFFFF}$f1score|^{15.0d}$}&{\color[HTML]{FFFFFF}$f1score|^{30.0d}$}&{\color[HTML]{FFFFFF}$f1score|^{60.0d}$}\\[0.25ex]
#
# ParallelRNN & 2 & 2 & GRU & 1 & 32 & 0 & {54.4$\pm$3.27} & {62.2$\pm$4.18} & {63.5$\pm$2.99} & {34.1$\pm$1.71} & {43.7$\pm$2.06} & {46.4$\pm$1.85} \\
# ParallelRNN & 2 & 4 & GRU & 1 & 32 & 0 & {53.3$\pm$1.76} & {63.1$\pm$5.05} & {65.1$\pm$2.44} & {39.3$\pm$2.48} & {48.2$\pm$4.73} & {51.1$\pm$3.17} \\
# ParallelRNN & 2 & 8 & GRU & 1 & 32 & 0 & {48.3$\pm$5.83} & {61.8$\pm$5.45} & {67.2$\pm$5.32} & {36.7$\pm$4.57} & {48.1$\pm$4.81} & {53.0$\pm$3.87} \\
# ParallelRNN & 3 & 0 & GRU & 1 & 32 & 0 & {55.5$\pm$4.08} & {60.0$\pm$2.83} & {56.7$\pm$2.61} & {31.0$\pm$1.98} & {36.5$\pm$1.28} & {38.1$\pm$1.02} \\
# SerialRNN & 2 & 2 & GRU & 1 & 64 & 0 & {54.5$\pm$1.91} & {68.3$\pm$2.13} & {65.8$\pm$2.77} & {34.6$\pm$0.25} & {48.2$\pm$2.0} & {49.9$\pm$2.91} \\
# SerialRNN & 2 & 4 & GRU & 1 & 64 & 0 & {52.2$\pm$2.98} & {70.3$\pm$2.01} & {71.1$\pm$3.15} & {39.1$\pm$1.48} & {54.4$\pm$2.73} & {56.4$\pm$2.21} \\
# SerialRNN & 2 & 8 & GRU & 1 & 64 & 0 & {54.7$\pm$2.77} & {60.9$\pm$3.46} & {64.5$\pm$2.3} & {39.6$\pm$1.46} & {48.2$\pm$3.75} & {52.6$\pm$2.43} \\
# SerialRNN & 3 & 0 & GRU & 1 & 64 & 0 & {52.2$\pm$1.51} & {62.5$\pm$4.18} & {61.4$\pm$4.36} & {29.9$\pm$0.87} & {38.9$\pm$2.54} & {40.0$\pm$2.52} \\
# \hline
#
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
# %load_ext autoreload
# %autoreload 2
from src.results.latex_tables import latex_table_metrics_mean

latex_table_metrics_mean(root_folder)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \begin{table*}
# \centering
# \caption{???}
# \label{results_columns}\vspace{.1cm}
# \begin{tabular}{lcccccc|cccc}\rowcolor[HTML]{343434}
#
# {\color[HTML]{FFFFFF}mdl}}&{\color[HTML]{FFFFFF}inD}&{\color[HTML]{FFFFFF}teD}&{\color[HTML]{FFFFFF}cell}&{\color[HTML]{FFFFFF}rnnL}&{\color[HTML]{FFFFFF}rnnU}&{\color[HTML]{FFFFFF}bi}&{\color[HTML]{FFFFFF}$|precision|_{1.0d}^{60.0d}$}&{\color[HTML]{FFFFFF}$|recall|_{1.0d}^{60.0d}$}&{\color[HTML]{FFFFFF}$|f1score|_{1.0d}^{60.0d}$}&{\color[HTML]{FFFFFF}$|baccu|_{1.0d}^{60.0d}$}\\[0.25ex]
#
# ParallelRNN & 2 & 2 & GRU & 1 & 32 & 0 & {40.3$\pm$1.08} & {59.1$\pm$1.88} & {39.8$\pm$1.21} & {59.1$\pm$1.88} \\
# ParallelRNN & 2 & 4 & GRU & 1 & 32 & 0 & {43.4$\pm$2.3} & {59.4$\pm$3.06} & {44.0$\pm$3.2} & {59.4$\pm$3.06} \\
# ParallelRNN & 2 & 8 & GRU & 1 & 32 & 0 & {44.0$\pm$2.16} & {58.1$\pm$4.46} & {44.3$\pm$3.53} & {58.1$\pm$4.46} \\
# ParallelRNN & 3 & 0 & GRU & 1 & 32 & 0 & {37.5$\pm$0.65} & {56.8$\pm$1.64} & {33.4$\pm$0.9} & {56.8$\pm$1.64} \\
# SerialRNN & 2 & 2 & GRU & 1 & 64 & 0 & {41.8$\pm$1.13} & {60.5$\pm$1.83} & {42.0$\pm$1.4} & {60.5$\pm$1.83} \\
# SerialRNN & 2 & 4 & GRU & 1 & 64 & 0 & {45.7$\pm$0.78} & {62.4$\pm$1.46} & {47.3$\pm$1.25} & {62.4$\pm$1.46} \\
# SerialRNN & 2 & 8 & GRU & 1 & 64 & 0 & {45.3$\pm$0.84} & {59.1$\pm$1.87} & {45.1$\pm$2.06} & {59.1$\pm$1.87} \\
# SerialRNN & 3 & 0 & GRU & 1 & 64 & 0 & {37.8$\pm$1.32} & {57.3$\pm$2.43} & {34.4$\pm$1.64} & {57.3$\pm$2.43} \\
# \hline
#
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
# %load_ext autoreload
# %autoreload 2
from src.results.latex_tables import latex_table_parameters

latex_table_parameters(root_folder)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-ParallelRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-32_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-2_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-2_teD-8_cell-GRU_rnnL-1_rnnU-64_bi-0
# model_name: mdl-SerialRNN_inD-3_teD-0_cell-GRU_rnnL-1_rnnU-64_bi-0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \begin{table*}
# \centering
# \caption{???}
# \label{results_columns}\vspace{.1cm}
# \begin{tabular}{lcccccc|ccc}\rowcolor[HTML]{343434}
#
# {\color[HTML]{FFFFFF}mdl}}&{\color[HTML]{FFFFFF}inD}&{\color[HTML]{FFFFFF}teD}&{\color[HTML]{FFFFFF}cell}&{\color[HTML]{FFFFFF}rnnL}&{\color[HTML]{FFFFFF}rnnU}&{\color[HTML]{FFFFFF}bi}&{\color[HTML]{FFFFFF}parameters}&{\color[HTML]{FFFFFF}epoch mins [mins]}&{\color[HTML]{FFFFFF}convergence mins [mins]}\\[0.25ex]
#
# ParallelRNN & 2 & 2 & GRU & 1 & 32 & 0 & {40,838} & {0.4$\pm$0.03} & {214.9$\pm$48.42} \\
# ParallelRNN & 2 & 4 & GRU & 1 & 32 & 0 & {41,094} & {0.4$\pm$0.02} & {228.8$\pm$31.09} \\
# ParallelRNN & 2 & 8 & GRU & 1 & 32 & 0 & {41,606} & {0.4$\pm$0.02} & {251.7$\pm$29.38} \\
# ParallelRNN & 3 & 0 & GRU & 1 & 32 & 0 & {40,582} & {0.4$\pm$0.01} & {253.0$\pm$46.12} \\
# SerialRNN & 2 & 2 & GRU & 1 & 64 & 0 & {68,101} & {0.4$\pm$0.01} & {440.4$\pm$111.94} \\
# SerialRNN & 2 & 4 & GRU & 1 & 64 & 0 & {68,613} & {0.4$\pm$0.01} & {327.6$\pm$101.82} \\
# SerialRNN & 2 & 8 & GRU & 1 & 64 & 0 & {69,637} & {0.4$\pm$0.02} & {477.8$\pm$45.13} \\
# SerialRNN & 3 & 0 & GRU & 1 & 64 & 0 & {67,461} & {0.4$\pm$0.01} & {393.5$\pm$78.29} \\
# \hline
#
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# /home/opimentel/TESIS/astrolightcurvesclassifier/src/results/utils.py:93: UserWarning: not same samples: [5, 5, 5, 5, 2, 5, 2, 5]
#   def get_info_from_models(root_folder, model_names, fext,

# %% [markdown]
# # confusion matrix plot

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from ipywidgets import interact, fixed
from flamingchoripan.myUtils.files import search_for_filedirs, load_pickle
from src.results.plots import plot_cm

def interact_f(model_name, target_day):
    return plot_cm(root_folder, model_name, target_day)

filedirs = search_for_filedirs(root_folder, fext='expmet', verbose=0)
model_names = list(set([fd.split('/')[-2] for fd in filedirs]))
target_days = load_pickle(filedirs[0])['days'][::-1]
interact(interact_f, model_name=model_names, target_day=target_days)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# > loading: ../SAVE_TESIS1/alerceZTFv5.1/results/mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1_rnnU-32_bi-0/id-1.val.expmet
# interactive(children=(Dropdown(description='model_name', options=('mdl-ParallelRNN_inD-2_teD-4_cell-GRU_rnnL-1…
# <function __main__.interact_f(model_name, target_day)>

# %%
# %load_ext autoreload
# %autoreload 2
from ipywidgets import interact, fixed
from flamingchoripan.myUtils.files import search_for_filedirs, load_pickle
from src.results.plots import animation_cm

filedirs = search_for_filedirs(root_folder, fext='expmet', verbose=0)
model_names = list(set([fd.split('/')[-2] for fd in filedirs]))
target_days = load_pickle(filedirs[0])['days']
animation_cm(root_folder, model_names[0], target_days)
